# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-80bea5481fc3> in <module>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/gdrive', force_remount=True)
#
# /usr/local/lib/python3.6/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms)
#     196   d.expect(prompt)
#     197   d.sendline('disown; exit')
# --> 198   d.expect(_pexpect.EOF)
#     199   assert not d.isalive()
#     200   assert d.exitstatus == 0
#
# /usr/local/lib/python3.6/dist-packages/pexpect/spawnbase.py in expect(self, pattern, timeout, searchwindowsize, async_, **kw)
#     339         compiled_pattern_list = self.compile_pattern_list(pattern)
#     340         return self.expect_list(compiled_pattern_list,
# --> 341                 timeout, searchwindowsize, async_)
#     342
# ...

# %%
# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools
# !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
# !apt-get update -qq 2>&1 > /dev/null
# !apt-get -y install -qq google-drive-ocamlfuse fuse
from google.colab import auth
auth.authenticate_user()
from oauth2client.client import GoogleCredentials
creds = GoogleCredentials.get_application_default()
import getpass
# !google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL
vcode = getpass.getpass()
# !echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}
# Out:
# E: Package 'python-software-properties' has no installation candidate
# Selecting previously unselected package google-drive-ocamlfuse.
# (Reading database ... 131304 files and directories currently installed.)
# Preparing to unpack .../google-drive-ocamlfuse_0.7.3-0ubuntu3~ubuntu18.04.1_amd64.deb ...
# Unpacking google-drive-ocamlfuse (0.7.3-0ubuntu3~ubuntu18.04.1) ...
# Setting up google-drive-ocamlfuse (0.7.3-0ubuntu3~ubuntu18.04.1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# ··········
# ...

# %%
# !ls 'gdrive/My Drive/ML-Progetto'
# Out:
#  average_scores.py     main.py			     renameSequentially.py
#  COMANDI.txt	       models.py		    'Running File.ipynb'
#  dataset	       model_zoo		     sample_data
#  dataset.py	       ops			     test_models.py
#  datasets_video.py     opts.py			     test_rgb_something.sh
#  dataset-test.ipynb    pretrain			     test_video.py
#  dataset-train.ipynb   process_dataset_charades.py   test_video.sh
#  download.sh	       process_dataset.py	     train_rgb_something.sh
#  extract_frames.py     ProvaInstagram.ipynb	     transforms.py
#  _gitignore.txt        __pycache__		     TRNmodule.py
#  _gitmodules.txt       README.md
#  LICENSE	       README.txt

# %%
# dataset something

# !python3 drive/Machine_Learning-Deep_Learning/PROGETTO_MACHINE_LEARNING/test_video.py --arch BNInception --dataset something  \
--weight drive/Machine_Learning-Deep_Learning/PROGETTO_MACHINE_LEARNING/pretrain/TRN_something_RGB_BNInception_TRNmultiscale_segment8_best.pth.tar \
--frame_folder drive/Machine_Learning-Deep_Learning/PROGETTO_MACHINE_LEARNING/sample_data/juggling_frames
# Out:
# Multi-Scale Temporal Relation Network Module in use ['8-frame relation', '7-frame relation', '6-frame relation', '5-frame relation', '4-frame relation', '3-frame relation', '2-frame relation']
# Freezing BatchNorm2D except the first one.
# Loading frames in drive/Machine_Learning-Deep_Learning/PROGETTO_MACHINE_LEARNING/sample_data/juggling_frames
# RESULT ON drive/Machine_Learning-Deep_Learning/PROGETTO_MACHINE_LEARNING/sample_data/juggling_frames
# 0.867 -> Throwing something in the air and catching it
# 0.121 -> Throwing something in the air and letting it fall
# 0.003 -> Hitting something with something
# 0.001 -> Something falling like a rock
# 0.001 -> Pretending to close something without actually closing it

# %%
# dataset moments

# !python3 drive/Machine_Learning-Deep_Learning/PROGETTO_MACHINE_LEARNING/test_video.py --arch InceptionV3 --dataset moments  \
--weight drive/Machine_Learning-Deep_Learning/PROGETTO_MACHINE_LEARNING/pretrain/TRN_moments_RGB_InceptionV3_TRNmultiscale_segment8_best.pth.tar \
--frame_folder drive/Machine_Learning-Deep_Learning/PROGETTO_MACHINE_LEARNING/sample_data/juggling_frames
# Out:
# Multi-Scale Temporal Relation Network Module in use ['8-frame relation', '7-frame relation', '6-frame relation', '5-frame relation', '4-frame relation', '3-frame relation', '2-frame relation']
# Freezing BatchNorm2D except the first one.
# Loading frames in drive/Machine_Learning-Deep_Learning/PROGETTO_MACHINE_LEARNING/sample_data/juggling_frames
# RESULT ON drive/Machine_Learning-Deep_Learning/PROGETTO_MACHINE_LEARNING/sample_data/juggling_frames
# 1.000 -> juggling
# 0.000 -> catching
# 0.000 -> balancing
# 0.000 -> spinning
# 0.000 -> performing

# %%
# dataset moments con video output

# !python3 drive/Machine_Learning-Deep_Learning/PROGETTO_MACHINE_LEARNING/test_video.py --arch InceptionV3 --dataset moments \
--weight drive/Machine_Learning-Deep_Learning/PROGETTO_MACHINE_LEARNING/pretrain/TRN_moments_RGB_InceptionV3_TRNmultiscale_segment8_best.pth.tar  \
--video_file drive/Machine_Learning-Deep_Learning/PROGETTO_MACHINE_LEARNING/sample_data/juggling.mp4 \
--rendered_output drive/Machine_Learning-Deep_Learning/PROGETTO_MACHINE_LEARNING/sample_data/predicted_video.mp4
# Out:
# Multi-Scale Temporal Relation Network Module in use ['8-frame relation', '7-frame relation', '6-frame relation', '5-frame relation', '4-frame relation', '3-frame relation', '2-frame relation']
# Freezing BatchNorm2D except the first one.
# Extracting frames using ffmpeg...
# RESULT ON drive/Machine_Learning-Deep_Learning/PROGETTO_MACHINE_LEARNING/sample_data/juggling.mp4
# 1.000 -> juggling
# 0.000 -> catching
# 0.000 -> balancing
# 0.000 -> spinning
# 0.000 -> flipping
# [MoviePy] >>>> Building video drive/Machine_Learning-Deep_Learning/PROGETTO_MACHINE_LEARNING/sample_data/predicted_video.mp4
# [MoviePy] Writing video drive/Machine_Learning-Deep_Learning/PROGETTO_MACHINE_LEARNING/sample_data/predicted_video.mp4
#  89% 8/9 [00:00<00:00, 574.16it/s]
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: drive/Machine_Learning-Deep_Learning/PROGETTO_MACHINE_LEARNING/sample_data/predicted_video.mp4

# %%
# video jumping.mp4 (orso con bambino)

# !python3 drive/Machine_Learning-Deep_Learning/PROGETTO_MACHINE_LEARNING/test_video.py --arch InceptionV3 --dataset moments  \
--weight drive/Machine_Learning-Deep_Learning/PROGETTO_MACHINE_LEARNING/pretrain/TRN_moments_RGB_InceptionV3_TRNmultiscale_segment8_best.pth.tar \
--frame_folder drive/Machine_Learning-Deep_Learning/PROGETTO_MACHINE_LEARNING/sample_data/jumping_frames
# Out:
# Imageio: 'ffmpeg-linux64-v3.3.1' was not found on your computer; downloading it now.
# Try 1. Download from https://github.com/imageio/imageio-binaries/raw/master/ffmpeg/ffmpeg-linux64-v3.3.1 (43.8 MB)
# 45929032/45929032 bytes (100.0%)
#   Done
# File saved as /root/.imageio/ffmpeg/ffmpeg-linux64-v3.3.1.
# Multi-Scale Temporal Relation Network Module in use ['8-frame relation', '7-frame relation', '6-frame relation', '5-frame relation', '4-frame relation', '3-frame relation', '2-frame relation']
# Freezing BatchNorm2D except the first one.
# Loading frames in drive/Machine_Learning-Deep_Learning/PROGETTO_MACHINE_LEARNING/sample_data/jumping_frames
# RESULT ON drive/Machine_Learning-Deep_Learning/PROGETTO_MACHINE_LEARNING/sample_data/jumping_frames
# 0.152 -> climbing
# 0.126 -> wetting
# 0.076 -> bathing
# 0.071 -> baptizing
# 0.067 -> hugging

# %%
# video jumping_video.mp4 (chitarrista che salta)

# !python3 drive/Machine_Learning-Deep_Learning/PROGETTO_MACHINE_LEARNING/test_video.py --arch InceptionV3 --dataset moments  \
--weight drive/Machine_Learning-Deep_Learning/PROGETTO_MACHINE_LEARNING/pretrain/TRN_moments_RGB_InceptionV3_TRNmultiscale_segment8_best.pth.tar \
--frame_folder drive/Machine_Learning-Deep_Learning/PROGETTO_MACHINE_LEARNING/sample_data/jumping_video_frames
# Out:
# Multi-Scale Temporal Relation Network Module in use ['8-frame relation', '7-frame relation', '6-frame relation', '5-frame relation', '4-frame relation', '3-frame relation', '2-frame relation']
# Freezing BatchNorm2D except the first one.
# Loading frames in drive/Machine_Learning-Deep_Learning/PROGETTO_MACHINE_LEARNING/sample_data/jumping_video_frames
# RESULT ON drive/Machine_Learning-Deep_Learning/PROGETTO_MACHINE_LEARNING/sample_data/jumping_video_frames
# 0.372 -> jumping
# 0.115 -> leaping
# 0.094 -> flipping
# 0.065 -> skipping
# 0.039 -> skating

# %%
# video put_something_on_something.mp4 (oggetto viene messo sopra un altro)

# !python3 drive/Machine_Learning-Deep_Learning/PROGETTO_MACHINE_LEARNING/test_video.py --arch BNInception --dataset something  \
--weight drive/Machine_Learning-Deep_Learning/PROGETTO_MACHINE_LEARNING/pretrain/TRN_something_RGB_BNInception_TRNmultiscale_segment8_best.pth.tar \
--frame_folder drive/Machine_Learning-Deep_Learning/PROGETTO_MACHINE_LEARNING/sample_data/something/put_something_on_something
# Out:
# Multi-Scale Temporal Relation Network Module in use ['8-frame relation', '7-frame relation', '6-frame relation', '5-frame relation', '4-frame relation', '3-frame relation', '2-frame relation']
# Freezing BatchNorm2D except the first one.
# Loading frames in drive/Machine_Learning-Deep_Learning/PROGETTO_MACHINE_LEARNING/sample_data/something/put_something_on_something
# RESULT ON drive/Machine_Learning-Deep_Learning/PROGETTO_MACHINE_LEARNING/sample_data/something/put_something_on_something
# 0.605 -> Pretending to put something onto something
# 0.229 -> Pretending to put something behind something
# 0.103 -> Putting something behind something
# 0.030 -> Holding something over something
# 0.024 -> Putting something onto something

# %%
# video let_something_fall.mp4 (far cadere un oggetto)

# !python3 drive/Machine_Learning-Deep_Learning/PROGETTO_MACHINE_LEARNING/test_video.py --arch BNInception --dataset something  \
--weight drive/Machine_Learning-Deep_Learning/PROGETTO_MACHINE_LEARNING/pretrain/TRN_something_RGB_BNInception_TRNmultiscale_segment8_best.pth.tar \
--frame_folder drive/Machine_Learning-Deep_Learning/PROGETTO_MACHINE_LEARNING/sample_data/something/let_something_fall
# Out:
# Multi-Scale Temporal Relation Network Module in use ['8-frame relation', '7-frame relation', '6-frame relation', '5-frame relation', '4-frame relation', '3-frame relation', '2-frame relation']
# Freezing BatchNorm2D except the first one.
# Loading frames in drive/Machine_Learning-Deep_Learning/PROGETTO_MACHINE_LEARNING/sample_data/something/let_something_fall
# RESULT ON drive/Machine_Learning-Deep_Learning/PROGETTO_MACHINE_LEARNING/sample_data/something/let_something_fall
# 0.309 -> Moving something down
# 0.292 -> Pretending to pick something up
# 0.117 -> Moving something towards the camera
# 0.048 -> Moving something across a surface without it falling down
# 0.047 -> Pushing something so that it almost falls off but doesn't

# %%
# extract frames from video  --video_folder (source folder of the .mp4 video)  --frame_folder (destination folder of the extracted frames)

# !python3 drive/Machine_Learning-Deep_Learning/PROGETTO_MACHINE_LEARNING/extract_frames.py  --video_folder drive/Machine_Learning-Deep_Learning/PROGETTO_MACHINE_LEARNING/sample_data/something \
--frame_folder drive/Machine_Learning-Deep_Learning/PROGETTO_MACHINE_LEARNING/sample_data/something
# Out:
# ffmpeg version 3.4.4-0ubuntu0.18.04.1 Copyright (c) 2000-2018 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.3.0-16ubuntu3)
# ...
